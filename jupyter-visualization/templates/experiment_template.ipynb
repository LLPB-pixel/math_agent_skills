# %% [markdown]
# # Reproducible mathematical experiment
#
# State the hypothesis, assumptions, and the distinction between exact, numerical, and empirical claims.

# %%
import numpy as np
import matplotlib.pyplot as plt

SEED = 42
rng = np.random.default_rng(SEED)
print(f'NumPy seed: {SEED}')

# %% [markdown]
# ## Definitions and parameters
#
# Keep model definitions and parameter choices in a separate cell.

# %%
# Define the experiment here.
pass

# %% [markdown]
# ## Computation and verification
#
# Compare against an analytical reference when one is available. Report tolerances and error measures.

# %%
# Compute the numerical result and its error here.
pass

# %% [markdown]
# ## Visualization
#
# Label axes, units, domains, and scales. A plot is an empirical diagnostic, not a proof.

# %%
# Create only the plots needed to answer the question.
# plt.figure()
# ...
# plt.show()
